# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("https://raw.githubusercontent.com/AshishJangra27/Data-Science-Specialization/main/Week%20-%209/Projects/country_vaccinations.csv")

# %%
df.head()
# Out:
#        country iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG 2021-02-22                   0                  0
# 1  Afghanistan      AFG 2021-02-23                   0                  0
# 2  Afghanistan      AFG 2021-02-24                   0                  0
# 3  Afghanistan      AFG 2021-02-25                   0                  0
# 4  Afghanistan      AFG 2021-02-26                   0                  0
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                        0                       0                   0
# 1                        0                       0                1367
# 2                        0                       0                1367
# 3                        0                       0                1367
# 4                        0                       0                1367
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
df.fillna(value = 0, inplace = True)
df.total_vaccinations = df.total_vaccinations.astype(int)
df.people_vaccinated = df.people_vaccinated.astype(int)
df.people_fully_vaccinated = df.people_fully_vaccinated.astype(int)
df.daily_vaccinations_raw = df.daily_vaccinations_raw.astype(int)
df.daily_vaccinations = df.daily_vaccinations.astype(int)
df.total_vaccinations_per_hundred = df.total_vaccinations_per_hundred.astype(int)
df.people_fully_vaccinated_per_hundred = df.people_fully_vaccinated_per_hundred.astype(int)
df.daily_vaccinations_per_million = df.daily_vaccinations_per_million.astype(int)
df.people_vaccinated_per_hundred = df.people_vaccinated_per_hundred.astype(int)
date = df.date.str.split('-', expand =True)
date
# Out:
#           0   1   2
# 0      2021  02  22
# 1      2021  02  23
# 2      2021  02  24
# 3      2021  02  25
# 4      2021  02  26
# ...     ...  ..  ..
# 86507  2022  03  25
# 86508  2022  03  26
# 86509  2022  03  27
# 86510  2022  03  28
# 86511  2022  03  29
#
# [86512 rows x 3 columns]

# %%
df['year'] = date[0]
df['month'] = date[1]
df['day'] = date[2]
df.year = pd.to_numeric(df.year)
df.month = pd.to_numeric(df.month)
df.day = pd.to_numeric(df.day)
df.date = pd.to_datetime(df.date)
df.head()
# Out:
#        country iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG 2021-02-22                   0                  0
# 1  Afghanistan      AFG 2021-02-23                   0                  0
# 2  Afghanistan      AFG 2021-02-24                   0                  0
# 3  Afghanistan      AFG 2021-02-25                   0                  0
# 4  Afghanistan      AFG 2021-02-26                   0                  0
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                        0                       0                   0
# 1                        0                       0                1367
# 2                        0                       0                1367
# 3                        0                       0                1367
# 4                        0                       0                1367
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %% [markdown]
# # find number of total vaccinations in 2020,2021,2022

# %%
total_vaccinations_2020=df[(df['country']=='India')&(df['year']==2020)]['total_vaccinations'].sum()

# %%
total_vaccinations_2020
# Out:
# 0

# %%
total_vaccinations_2021=df[(df['country']=='India')&(df['year']==2021)]['total_vaccinations'].sum()

# %%
total_vaccinations_2021
# Out:
# 174118546779

# %%
total_vaccinations_2022=df[(df['country']=='India')&(df['year']==2022)]['total_vaccinations'].sum()

# %%
total_vaccinations_2022
# Out:
# 149321759019

# %% [markdown]
# # compare total_vaccinations in 2021 india vs usa

# %%
India_df=df[df.country=="India"]

# %%
India_df
# Out:
#       country iso_code       date  total_vaccinations  people_vaccinated  \
# 35372   India      IND 2021-01-15                   0                  0
# 35373   India      IND 2021-01-16              191181             191181
# 35374   India      IND 2021-01-17              224301             224301
# 35375   India      IND 2021-01-18              454049             454049
# 35376   India      IND 2021-01-19              674835             674835
# ...       ...      ...        ...                 ...                ...
# 35806   India      IND 2022-03-25          1826265830          980435665
# 35807   India      IND 2022-03-26          1830285290          982687842
# 35808   India      IND 2022-03-27          1831347741          983190780
# 35809   India      IND 2022-03-28          1833040014          984051283
# 35810   India      IND 2022-03-29          1834500657          984838143
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# ...

# %%
USA_df=df[df.country=="USA"]

# %%
USA_df
# Out:
# Empty DataFrame
# Columns: [country, iso_code, date, total_vaccinations, people_vaccinated, people_fully_vaccinated, daily_vaccinations_raw, daily_vaccinations, total_vaccinations_per_hundred, people_vaccinated_per_hundred, people_fully_vaccinated_per_hundred, daily_vaccinations_per_million, vaccines, source_name, source_website, year, month, day]
# Index: []

# %%
India_year_2020=India_df['year']==2020

# %%
India_year_2020
# Out:
# 35372    False
# 35373    False
# 35374    False
# 35375    False
# 35376    False
#          ...
# 35806    False
# 35807    False
# 35808    False
# 35809    False
# 35810    False
# Name: year, Length: 439, dtype: bool

# %%
India_vaccinations=India_df['total_vaccinations']

# %%
India_vaccinations
# Out:
# 35372             0
# 35373        191181
# 35374        224301
# 35375        454049
# 35376        674835
#             ...
# 35806    1826265830
# 35807    1830285290
# 35808    1831347741
# 35809    1833040014
# 35810    1834500657
# Name: total_vaccinations, Length: 439, dtype: int32

# %%
USA_year_2020=USA_df['year']==2020

# %%
USA_year_2020
# Out:
# Series([], Name: year, dtype: bool)

# %%
USA_vaccinations=USA_df['total_vaccinations']

# %%
USA_vaccinations
# Out:
# Series([], Name: total_vaccinations, dtype: int32)

# %%
plt.plot(India_year_2020,India_vaccinations,label="India")
plt.plot(USA_year_2020,USA_vaccinations,label="USA")
plt.xlabel("year")
plt.ylabel("total_vaccinations")
plt.title("India vs USA;total_vaccinations in 2020")
plt.legend()
# Out:
# C:\Users\chandrikathupakula\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:2064: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# C:\Users\chandrikathupakula\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:248: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# C:\Users\chandrikathupakula\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:250: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %% [markdown]
# # compare total_vacccinations in 2022 india vs china

# %%
India_year_2021=India_df['year']==2021

# %%
India_year_2021
# Out:
# 35372     True
# 35373     True
# 35374     True
# 35375     True
# 35376     True
#          ...
# 35806    False
# 35807    False
# 35808    False
# 35809    False
# 35810    False
# Name: year, Length: 439, dtype: bool

# %%
China_df=df[df.country=="China"]

# %%
China_df
# Out:
#       country iso_code       date  total_vaccinations  people_vaccinated  \
# 15756   China      CHN 2020-12-15             1500000                  0
# 15757   China      CHN 2020-12-16                   0                  0
# 15758   China      CHN 2020-12-17                   0                  0
# 15759   China      CHN 2020-12-18                   0                  0
# 15760   China      CHN 2020-12-19                   0                  0
# ...       ...      ...        ...                 ...                ...
# 16221   China      CHN 2022-03-25         -2147483648                  0
# 16222   China      CHN 2022-03-26         -2147483648                  0
# 16223   China      CHN 2022-03-27         -2147483648                  0
# 16224   China      CHN 2022-03-28         -2147483648                  0
# 16225   China      CHN 2022-03-29         -2147483648                  0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# ...

# %%
China_year_2021=China_df['year']==2021

# %%
China_year_2021
# Out:
# 15756    False
# 15757    False
# 15758    False
# 15759    False
# 15760    False
#          ...
# 16221    False
# 16222    False
# 16223    False
# 16224    False
# 16225    False
# Name: year, Length: 470, dtype: bool

# %%
China_vaccinations=China_df['total_vaccinations']

# %%
China_vaccinations
# Out:
# 15756       1500000
# 15757             0
# 15758             0
# 15759             0
# 15760             0
#             ...
# 16221   -2147483648
# 16222   -2147483648
# 16223   -2147483648
# 16224   -2147483648
# 16225   -2147483648
# Name: total_vaccinations, Length: 470, dtype: int32

# %%
plt.plot(India_year_2021,India_vaccinations,label="India")
plt.plot(China_year_2021,China_vaccinations,label="China")
plt.xlabel("year")
plt.ylabel("total_vaccinations")
plt.title("India vs China;total_vaccinations in 2021")
plt.legend()
# Out:
# C:\Users\chandrikathupakula\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:2064: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# C:\Users\chandrikathupakula\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:248: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# C:\Users\chandrikathupakula\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:250: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %% [markdown]
# # find number of vaccinations in india in 2020 each month

# %%
total_vaccinations_2020=df[(df['country']=='India')&(df['month'])]['total_vaccinations'].sum()

# %%
total_vaccinations_2020
# Out:
# 175976801171

# %% [markdown]
# #  most totalvaccinations in 2021 in india

# %%
total_vaccinations_2021=df[(df['country']=='India')&(df['month'])]['total_vaccinations']

# %%
total_vaccinations_2021
# Out:
# 35372             0
# 35373        191181
# 35374        224301
# 35375        454049
# 35376        674835
#             ...
# 35806    1826265830
# 35807    1830285290
# 35808    1831347741
# 35809    1833040014
# 35810    1834500657
# Name: total_vaccinations, Length: 230, dtype: int32

# %%
max_value=df['total_vaccinations'].idxmax()

# %%
max_value
# Out:
# 16026

# %%
max_value_month=df.loc[max_value,'month']

# %%
max_value_month
# Out:
# 9
